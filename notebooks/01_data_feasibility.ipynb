# %% [markdown]
# # Pre-Model Data Readiness
#
# This notebook inspects the approved Twelve Data demo result and the 88-security SEC sector audit. It does not issue network requests.

# %%
from pathlib import Path
import json
import pandas as pd
import yaml

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
OUTPUT_DIR = PROJECT_ROOT / 'outputs' / 'pre_model_validation'

# %%
market_demo = pd.read_csv(OUTPUT_DIR / 'market_coverage_demo.csv')
sec_sample = pd.read_csv(OUTPUT_DIR / 'sec_validation_sample.csv')
field_coverage = pd.read_csv(OUTPUT_DIR / 'sec_field_coverage.csv')
sector_coverage = pd.read_csv(OUTPUT_DIR / 'sec_sector_coverage.csv')
sec_summary = json.loads((OUTPUT_DIR / 'sec_coverage_summary.json').read_text())
data_contract = yaml.safe_load((PROJECT_ROOT / 'config' / 'data_contract.yaml').read_text())
sec_summary

# %%
market_demo

# %%
field_coverage.sort_values('missing_rate', ascending=False)

# %%
sector_coverage.loc[sector_coverage['missing_rate'] >= 0.25].sort_values(
    ['field', 'sector']
)

# %% [markdown]
# Read `outputs/pre_model_validation/pre_model_readiness_report.md` for the remaining gate before factor-model development.
